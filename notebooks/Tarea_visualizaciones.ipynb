# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
dfene = pd.read_csv("../input/sales_2017_enero.csv")

# %%
dffeb = pd.read_csv("../input/sales_2017_febrero.csv")

# %%
dfmar = pd.read_csv("../input/sales_2017_marzo.csv")

# %%
stores = pd.read_csv("../input/stores.csv")

# %%
oil = pd.read_csv("../input/oil.csv")

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil["date"] = pd.to_datetime(oil.date)

# %%
oil2015 = oil.loc[(oil["date"]>="2015-01-01")&(oil["date"]<="2015-12-31")]

# %%
oil2015.fillna(oil2015["dcoilwtico"].mean(),inplace= True)
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\1444324482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2015.fillna(oil2015["dcoilwtico"].mean(),inplace= True)

# %%
media2015 = oil2015.dcoilwtico.mean()
std2015 = oil2015.dcoilwtico.std()

# %%
oil2015["zscore"] = (oil2015.dcoilwtico - media2015)/std2015
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\2339226576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2015["zscore"] = (oil2015.dcoilwtico - media2015)/std2015

# %%
oil2015
# Out:
#           date  dcoilwtico        zscore
# 522 2015-01-01   48.656706  1.059167e-15
# 523 2015-01-02   52.720000  6.056929e-01
# 524 2015-01-05   50.050000  2.076907e-01
# 525 2015-01-06   47.980000 -1.008729e-01
# 526 2015-01-07   48.690000  4.962902e-03
# ..         ...         ...           ...
# 778 2015-12-25   48.656706  1.059167e-15
# 779 2015-12-28   36.360000 -1.833003e+00
# 780 2015-12-29   37.880000 -1.606425e+00
# 781 2015-12-30   36.590000 -1.798718e+00
# 782 2015-12-31   37.130000 -1.718223e+00
#
# [261 rows x 3 columns]

# %%
oil2015ene = oil2015.loc[(oil2015["date"]>="2015-01-01")&(oil2015["date"]<="2015-01-30")]
oil2015feb = oil2015.loc[(oil2015["date"]>="2015-02-01")&(oil2015["date"]<="2015-02-28")]
oil2015mar = oil2015.loc[(oil2015["date"]>="2015-03-01")&(oil2015["date"]<="2015-03-31")]
oil2015abr = oil2015.loc[(oil2015["date"]>="2015-04-01")&(oil2015["date"]<="2015-04-30")]
oil2015may = oil2015.loc[(oil2015["date"]>="2015-05-01")&(oil2015["date"]<="2015-05-30")]
oil2015jun = oil2015.loc[(oil2015["date"]>="2015-06-01")&(oil2015["date"]<="2015-06-30")]
oil2015jul = oil2015.loc[(oil2015["date"]>="2015-07-01")&(oil2015["date"]<="2015-07-31")]
oil2015ago = oil2015.loc[(oil2015["date"]>="2015-08-01")&(oil2015["date"]<="2015-08-31")]
oil2015sep = oil2015.loc[(oil2015["date"]>="2015-09-01")&(oil2015["date"]<="2015-09-30")]
oil2015oct = oil2015.loc[(oil2015["date"]>="2015-10-01")&(oil2015["date"]<="2015-10-30")]
oil2015nov = oil2015.loc[(oil2015["date"]>="2015-11-01")&(oil2015["date"]<="2015-11-30")]
oil2015dic = oil2015.loc[(oil2015["date"]>="2015-12-01")&(oil2015["date"]<="2015-12-31")]

# %%
serene2015 = oil2015ene.groupby("date")["dcoilwtico"].sum()
serfeb2015 = oil2015feb.groupby("date")["dcoilwtico"].sum()
sermar2015 = oil2015mar.groupby("date")["dcoilwtico"].sum()
serabr2015 = oil2015abr.groupby("date")["dcoilwtico"].sum()
sermay2015 = oil2015may.groupby("date")["dcoilwtico"].sum()
serjun2015 = oil2015jun.groupby("date")["dcoilwtico"].sum()
serjul2015 = oil2015jul.groupby("date")["dcoilwtico"].sum()
serago2015 = oil2015ago.groupby("date")["dcoilwtico"].sum()
sersep2015 = oil2015sep.groupby("date")["dcoilwtico"].sum()
seroct2015 = oil2015oct.groupby("date")["dcoilwtico"].sum()
sernov2015 = oil2015nov.groupby("date")["dcoilwtico"].sum()
serdic2015 = oil2015dic.groupby("date")["dcoilwtico"].sum()

# %%
oil2016 = oil.loc[(oil["date"]>="2016-01-01")&(oil["date"]<="2016-12-31")]

# %%
oil2016.fillna(oil2016["dcoilwtico"].mean(),inplace= True)
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\2770476057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2016.fillna(oil2016["dcoilwtico"].mean(),inplace= True)

# %%
media2016 = oil2016.dcoilwtico.mean()
std2016 = oil2016.dcoilwtico.std()

# %%
oil2016["zscore"] = (oil2016.dcoilwtico - media2016)/std2016
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\4051499339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2016["zscore"] = (oil2016.dcoilwtico - media2016)/std2016

# %%
oil2016ene = oil2016.loc[(oil2016["date"]>="2016-01-01")&(oil2016["date"]<="2016-01-30")]
oil2016feb = oil2016.loc[(oil2016["date"]>="2016-02-01")&(oil2016["date"]<="2016-02-28")]
oil2016mar = oil2016.loc[(oil2016["date"]>="2016-03-01")&(oil2016["date"]<="2016-03-31")]
oil2016abr = oil2016.loc[(oil2016["date"]>="2016-04-01")&(oil2016["date"]<="2016-04-30")]
oil2016may = oil2016.loc[(oil2016["date"]>="2016-05-01")&(oil2016["date"]<="2016-05-30")]
oil2016jun = oil2016.loc[(oil2016["date"]>="2016-06-01")&(oil2016["date"]<="2016-06-30")]
oil2016jul = oil2016.loc[(oil2016["date"]>="2016-07-01")&(oil2016["date"]<="2016-07-31")]
oil2016ago = oil2016.loc[(oil2016["date"]>="2016-08-01")&(oil2016["date"]<="2016-08-31")]
oil2016sep = oil2016.loc[(oil2016["date"]>="2016-09-01")&(oil2016["date"]<="2016-09-30")]
oil2016oct = oil2016.loc[(oil2016["date"]>="2016-10-01")&(oil2016["date"]<="2016-10-30")]
oil2016nov = oil2016.loc[(oil2016["date"]>="2016-11-01")&(oil2016["date"]<="2016-11-30")]
oil2016dic = oil2016.loc[(oil2016["date"]>="2016-12-01")&(oil2016["date"]<="2016-12-31")]

# %%
serene2016 = oil2016ene.groupby("date")["dcoilwtico"].sum()
serfeb2016 = oil2016feb.groupby("date")["dcoilwtico"].sum()
sermar2016 = oil2016mar.groupby("date")["dcoilwtico"].sum()
serabr2016 = oil2016abr.groupby("date")["dcoilwtico"].sum()
sermay2016 = oil2016may.groupby("date")["dcoilwtico"].sum()
serjun2016 = oil2016jun.groupby("date")["dcoilwtico"].sum()
serjul2016 = oil2016jul.groupby("date")["dcoilwtico"].sum()
serago2016 = oil2016ago.groupby("date")["dcoilwtico"].sum()
sersep2016 = oil2016sep.groupby("date")["dcoilwtico"].sum()
seroct2016 = oil2016oct.groupby("date")["dcoilwtico"].sum()
sernov2016 = oil2016nov.groupby("date")["dcoilwtico"].sum()
serdic2016 = oil2016dic.groupby("date")["dcoilwtico"].sum()

# %%
oil2017 = oil.loc[(oil["date"]>="2017-01-01")&(oil["date"]<="2017-12-31")]

# %%
oil2017.fillna(oil2017["dcoilwtico"].mean(),inplace= True)
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\3013819177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2017.fillna(oil2017["dcoilwtico"].mean(),inplace= True)

# %%
media2017 = oil2017.dcoilwtico.mean()
std2017 = oil2017.dcoilwtico.std()

# %%
oil2017["zscore"] = (oil2017.dcoilwtico - media2017)/std2017
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11036\2374696108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil2017["zscore"] = (oil2017.dcoilwtico - media2017)/std2017

# %%
oil2017ene = oil2017.loc[(oil2017["date"]>="2017-01-01")&(oil2017["date"]<="2017-01-30")]
oil2017feb = oil2017.loc[(oil2017["date"]>="2017-02-01")&(oil2017["date"]<="2017-02-28")]
oil2017mar = oil2017.loc[(oil2017["date"]>="2017-03-01")&(oil2017["date"]<="2017-03-31")]
oil2017abr = oil2017.loc[(oil2017["date"]>="2017-04-01")&(oil2017["date"]<="2017-04-30")]
oil2017may = oil2017.loc[(oil2017["date"]>="2017-05-01")&(oil2017["date"]<="2017-05-30")]
oil2017jun = oil2017.loc[(oil2017["date"]>="2017-06-01")&(oil2017["date"]<="2017-06-30")]
oil2017jul = oil2017.loc[(oil2017["date"]>="2017-07-01")&(oil2017["date"]<="2017-07-31")]
oil2017ago = oil2017.loc[(oil2017["date"]>="2017-08-01")&(oil2017["date"]<="2017-08-31")]
oil2017sep = oil2017.loc[(oil2017["date"]>="2017-09-01")&(oil2017["date"]<="2017-09-30")]
oil2017oct = oil2017.loc[(oil2017["date"]>="2017-10-01")&(oil2017["date"]<="2017-10-30")]
oil2017nov = oil2017.loc[(oil2017["date"]>="2017-11-01")&(oil2017["date"]<="2017-11-30")]
oil2017dic = oil2017.loc[(oil2017["date"]>="2017-12-01")&(oil2017["date"]<="2017-12-31")]

# %%
serene2017 = oil2017ene.groupby("date")["dcoilwtico"].sum()
serfeb2017 = oil2017feb.groupby("date")["dcoilwtico"].sum()
sermar2017 = oil2017mar.groupby("date")["dcoilwtico"].sum()
serabr2017 = oil2017abr.groupby("date")["dcoilwtico"].sum()
sermay2017 = oil2017may.groupby("date")["dcoilwtico"].sum()
serjun2017 = oil2017jun.groupby("date")["dcoilwtico"].sum()
serjul2017 = oil2017jul.groupby("date")["dcoilwtico"].sum()
serago2017 = oil2017ago.groupby("date")["dcoilwtico"].sum()
sersep2017 = oil2017sep.groupby("date")["dcoilwtico"].sum()
seroct2017 = oil2017oct.groupby("date")["dcoilwtico"].sum()
sernov2017 = oil2017nov.groupby("date")["dcoilwtico"].sum()
serdic2017 = oil2017dic.groupby("date")["dcoilwtico"].sum()

# %%
fig, ax = plt.subplots(4,3, figsize=(10,10))
_ = fig.suptitle("Ventas por mes en 2015,2016 y 2017", fontsize=20)
_ = ax[0,0].set_ylim(0,111)
_ = ax[0,0].set_title("Enero",{"fontsize":16})
_ = sns.lineplot(serene2015,ax=ax[0,0], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serene2016,ax=ax[0,0], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serene2017,ax=ax[0,0], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[0,1].set_ylim(0,111)
_ = ax[0,1].set_title("Febrero",{"fontsize":16})
_ = sns.lineplot(serfeb2015,ax=ax[0,1], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serfeb2016,ax=ax[0,1], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serfeb2017,ax=ax[0,1], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[0,2].set_ylim(0,111)
_ = ax[0,2].set_title("Marzo",{"fontsize":16})
_ = sns.lineplot(sermar2015,ax=ax[0,2], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(sermar2016,ax=ax[0,2], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(sermar2017,ax=ax[0,2], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[1,0].set_ylim(0,111)
_ = ax[1,0].set_title("Abril",{"fontsize":16})
_ = sns.lineplot(serabr2015,ax=ax[1,0], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serabr2016,ax=ax[1,0], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serabr2017,ax=ax[1,0], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[1,1].set_ylim(0,111)
_ = ax[1,1].set_title("Mayo",{"fontsize":16})
_ = sns.lineplot(sermay2015,ax=ax[1,1], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(sermay2016,ax=ax[1,1], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(sermay2017,ax=ax[1,1], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[1,2].set_ylim(0,111)
_ = ax[1,2].set_title("Junio",{"fontsize":16})
_ = sns.lineplot(serjun2015,ax=ax[1,2], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serjun2016,ax=ax[1,2], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serjun2017,ax=ax[1,2], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[2,0].set_ylim(0,111)
_ = ax[2,0].set_title("Julio",{"fontsize":16})
_ = sns.lineplot(serjul2015,ax=ax[2,0], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serjul2016,ax=ax[2,0], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serjul2017,ax=ax[2,0], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[2,1].set_ylim(0,111)
_ = ax[2,1].set_title("Agosto",{"fontsize":16})
_ = sns.lineplot(serago2015,ax=ax[2,1], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serago2016,ax=ax[2,1], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serago2017,ax=ax[2,1], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[2,2].set_ylim(0,111)
_ = ax[2,2].set_title("Septiembre",{"fontsize":16})
_ = sns.lineplot(sersep2015,ax=ax[2,2], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(sersep2016,ax=ax[2,2], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(sersep2017,ax=ax[2,2], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[3,0].set_ylim(0,111)
_ = ax[3,0].set_title("Octubre",{"fontsize":16})
_ = sns.lineplot(seroct2015,ax=ax[3,0], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(seroct2016,ax=ax[3,0], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(seroct2017,ax=ax[3,0], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")


_ = ax[3,1].set_ylim(0,111)
_ = ax[3,1].set_title("Noviembre",{"fontsize":16})
_ = sns.lineplot(sernov2015,ax=ax[3,1], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(sernov2016,ax=ax[3,1], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(sernov2017,ax=ax[3,1], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_ = ax[3,2].set_ylim(0,111)
_ = ax[3,2].set_title("Diciembre",{"fontsize":16})
_ = sns.lineplot(serdic2015,ax=ax[3,2], color="b", marker="s", mfc = "k", linestyle = "--", label="2015")
_ = sns.lineplot(serdic2016,ax=ax[3,2], color="r", marker="s", mfc = "k", linestyle = "--", label="2016")
_ = sns.lineplot(serdic2017,ax=ax[3,2], color="y", marker="s", mfc = "k", linestyle = "--", label="2017")

_=plt.xticks(rotation = 90)

# %%
sns.histplot(oil2015['zscore'], kde=True, label='2015', color='blue', alpha=0.5)
sns.histplot(oil2016['zscore'], kde=True, label='2016', color='green', alpha=0.5)
sns.histplot(oil2017['zscore'], kde=True, label='2017', color='red', alpha=0.5)
plt.title('Distribución del Precio del Petróleo (2015-2017)')
plt.xlabel('zscore')
plt.ylabel('Frecuencia')
plt.legend(title='Año')

# %%
stores = stores.loc[stores.city!="Quito",:]	
stores = stores.loc[stores.city!="Guayaquil",:]

# %%
dfene = dfene.merge(stores, on="store_nbr")
dffeb = dfene.merge(stores, on="store_nbr")
dfmar = dfene.merge(stores, on="store_nbr")

# %%
dfene["date"] = pd.to_datetime(dfene.date)
dfene["day"] = dfene.date.dt.day_name()
table1 = pd.pivot_table(data=dfene, index="day", columns="state", values="unit_sales", aggfunc="sum").fillna(0)

# %%
dffeb["date"] = pd.to_datetime(dffeb.date)
dffeb["day"] = dffeb.date.dt.day_name()
table2 = pd.pivot_table(data=dffeb, index="day", columns="state_x", values="unit_sales", aggfunc="sum").fillna(0)

# %%
dfmar["date"] = pd.to_datetime(dfmar.date)
dfmar["day"] = dfmar.date.dt.day_name()
table3 = pd.pivot_table(data=dfmar, index="day", columns="state_x", values="unit_sales", aggfunc="sum").fillna(0)

# %%
table1
# Out:
# state           Azuay    Bolivar  Chimborazo   Cotopaxi      El Oro  \
# day
# Friday     164248.108  27834.742   25262.399  48293.296   91894.310
# Monday     240912.924  48685.908   42901.373  81897.103  143720.372
# Saturday   224358.020  53225.244   42699.158  69677.884  124701.638
# Sunday     209723.780  39598.749   29940.453  63344.399  129132.552
# Thursday   144806.051  26502.505   27918.249  48696.940   87940.609
# Tuesday    222784.773  42998.583   41830.739  73805.608  143070.808
# Wednesday  191293.166  31254.763   28480.156  53305.788  111285.730
#
# state      Esmeraldas      Guayas   Imbabura       Loja    Los Rios  \
# day
# Friday      45711.717  113445.092  28117.381  48156.001   71180.799
# Monday      75081.792  176430.292  46651.025  68527.955  117805.001
# Saturday    58224.391  147645.196  35116.368  76077.452  106960.091
# Sunday      71496.731  172707.941  33337.588  72858.874  121882.239
# Thursday    47272.745  103542.217  28896.106  36280.082   74981.049
# ...

# %%
sns.heatmap(table1,cmap="Greens")
sns.heatmap(table2,cmap="magma")
sns.heatmap(table3,cmap="Purples")
# Out:
# <Axes: xlabel='state_x', ylabel='day'>
