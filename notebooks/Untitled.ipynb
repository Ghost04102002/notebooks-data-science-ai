# %% [markdown]
# # 1) Imports y configuración

# %%
import os, random, math
from pathlib import Path
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
SEED       = 42
IMG_SIZE   = 160         # 128–224 suele ir bien; 160 es un buen equilibrio
BATCH_SIZE = 64
EPOCHS     = 200
DATA_DIR   = r'C:/Users/sebas/OneDrive/Desktop/ProyectoIA/UTKFace'   # carpeta con imágenes (UTKFace-like)
VAL_SPLIT  = 0.10
TEST_SPLIT = 0.10

# %%
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # 2) Utilidades: parsear edad e imagen

# %%
def parse_age_from_filename(path):
    """
    Para UTKFace: el nombre empieza con la edad, p. ej. '23_0_0_20170109150557335.jpg'
    Ajusta esto si tu dataset es distinto.
    """
    fname = tf.strings.split(path, os.sep)[-1]          # basename
    age_str = tf.strings.split(fname, "_")[0]           # '23'
    age = tf.strings.to_number(age_str, out_type=tf.float32)
    return age

# %%
def load_and_preprocess(path):
    img_bytes = tf.io.read_file(path)
    # UTKFace suele ser JPG; si tienes PNG usa decode_png
    img = tf.io.decode_jpeg(img_bytes, channels=3)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.image.convert_image_dtype(img, tf.float32)  # [0,1]
    age = parse_age_from_filename(path)
    return img, age

# %% [markdown]
# # 3) Listado y split de archivos

# %%
all_files = []
for ext in ("*.jpg", "*.jpeg", "*.png"):
    all_files += list(Path(DATA_DIR).glob(ext))
all_files = [str(p) for p in all_files]
if not all_files:
    raise RuntimeError("No se encontraron imágenes. Revisa DATA_DIR y extensiones.")

# %%
random.shuffle(all_files)
N = len(all_files)
n_test = int(N * TEST_SPLIT)
n_val  = int(N * VAL_SPLIT)
n_train = N - n_val - n_test

# %%
train_files = all_files[:n_train]
val_files   = all_files[n_train:n_train+n_val]
test_files  = all_files[n_train+n_val:]

# %%
print(f"Train: {len(train_files)} | Val: {len(val_files)} | Test: {len(test_files)}")
# Out:
# Train: 18968 | Val: 2370 | Test: 2370

# %% [markdown]
# # 4) tf.data pipelines con augmentations

# %%
AUTOTUNE = tf.data.AUTOTUNE

data_augment = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augment")

def make_ds(filepaths, training):
    ds = tf.data.Dataset.from_tensor_slices(filepaths)
    ds = ds.shuffle(buffer_size=min(len(filepaths), 2000), seed=SEED) if training else ds
    ds = ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    if training:
        ds = ds.map(lambda x, y: (data_augment(x, training=True), y), num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds = make_ds(train_files, training=True)
val_ds   = make_ds(val_files, training=False)
test_ds  = make_ds(test_files, training=False)

# %% [markdown]
# # 5) Modelo: CNN residual ligera para regresión

# %%
def conv_bn_act(x, filters, k=3, s=1):
    x = layers.Conv2D(filters, k, strides=s, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)
    return x

def residual_block(x, filters, stride=1):
    shortcut = x
    x = conv_bn_act(x, filters, 3, stride)
    x = conv_bn_act(x, filters, 3, 1)
    # Proyección si cambia canales o stride
    if shortcut.shape[-1] != filters or stride != 1:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding="same", use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("swish")(x)
    return x

def build_model(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    inputs = keras.Input(shape=input_shape)
    # Stem
    x = conv_bn_act(inputs, 32, 3, 2)
    x = residual_block(x, 32, 1)
    x = residual_block(x, 32, 1)

    # Downsample + bloques
    x = residual_block(x, 64, 2)
    x = residual_block(x, 64, 1)

    x = residual_block(x, 128, 2)
    x = residual_block(x, 128, 1)
    x = residual_block(x, 128, 1)

    x = residual_block(x, 256, 2)
    x = residual_block(x, 256, 1)

    # Cabeza
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(256, activation="swish")(x)
    x = layers.Dropout(0.2)(x)
    # Salida: una sola neurona lineal (años)
    outputs = layers.Dense(1, activation="linear", dtype="float32")(x)  # fuerza float32 si usas mixed precision

    model = keras.Model(inputs, outputs, name="AgeRegressorCNN")
    return model

model = build_model()
model.summary()
# Out:
# Model: "AgeRegressorCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 80, 80,    │        864 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 80, 80,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 80, 80,    │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │      9,216 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 80, 80,    │          0 │ activation_2[0][… │
# │                     │ 32)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 80, 80,    │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │      9,216 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 80, 80,    │      9,216 │ activation_4[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 80, 80,    │          0 │ activation_5[0][… │
# │                     │ 32)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 80, 80,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │     18,432 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 40, 40,    │     36,864 │ activation_7[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 40, 40,    │      2,048 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 40, 40,    │          0 │ activation_8[0][… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 40, 40,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 40, 40,    │     36,864 │ activation_9[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 40, 40,    │     36,864 │ activation_10[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 40, 40,    │          0 │ activation_11[0]… │
# │                     │ 64)               │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 20, 20,    │     73,728 │ activation_12[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 20, 20,    │    147,456 │ activation_13[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 20, 20,    │      8,192 │ activation_12[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 20, 20,    │          0 │ activation_14[0]… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 20, 20,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 20, 20,    │    147,456 │ activation_15[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 20, 20,    │    147,456 │ activation_16[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 20, 20,    │          0 │ activation_17[0]… │
# │                     │ 128)              │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 20, 20,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 20, 20,    │    147,456 │ activation_18[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 20, 20,    │    147,456 │ activation_19[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 20, 20,    │          0 │ activation_20[0]… │
# │                     │ 128)              │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 20, 20,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 10, 10,    │    294,912 │ activation_21[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 10, 10,    │    589,824 │ activation_22[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 10, 10,    │     32,768 │ activation_21[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 10, 10,    │          0 │ activation_23[0]… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 10, 10,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 10, 10,    │    589,824 │ activation_24[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 10, 10,    │    589,824 │ activation_25[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 10, 10,    │          0 │ activation_26[0]… │
# │                     │ 256)              │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 10, 10,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_27[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,161,825 (12.06 MB)
#  Trainable params: 3,156,513 (12.04 MB)
#  Non-trainable params: 5,312 (20.75 KB)

# %% [markdown]
# # 6) Compilación, callbacks y entrenamiento

# %%
loss = keras.losses.Huber(delta=5.0)
metrics = [
    keras.metrics.MeanAbsoluteError(name="mae"),
    keras.metrics.RootMeanSquaredError(name="rmse"),
]

optimizer = keras.optimizers.Adam(learning_rate=1e-3)

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

ckpt_path = "best_age_model.keras"
callbacks = [
    keras.callbacks.ModelCheckpoint(ckpt_path, monitor="val_mae", save_best_only=True, mode="min"),
    keras.callbacks.ReduceLROnPlateau(monitor="val_mae", factor=0.5, patience=5, min_lr=1e-6, mode="min", verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_mae", patience=15, restore_best_weights=True, mode="min", verbose=1),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 972s 3s/step - loss: 58.7236 - mae: 14.0034 - rmse: 19.0581 - val_loss: 76.0428 - val_mae: 17.5707 - val_rmse: 22.5414 - learning_rate: 0.0010
# Epoch 2/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 941s 3s/step - loss: 42.5878 - mae: 10.7109 - rmse: 14.8491 - val_loss: 47.7337 - val_mae: 11.7835 - val_rmse: 15.3484 - learning_rate: 0.0010
# Epoch 3/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 939s 3s/step - loss: 32.9139 - mae: 8.6962 - rmse: 12.0169 - val_loss: 37.4495 - val_mae: 9.5787 - val_rmse: 13.7128 - learning_rate: 0.0010
# Epoch 4/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 928s 3s/step - loss: 29.5997 - mae: 7.9966 - rmse: 11.1215 - val_loss: 43.8491 - val_mae: 10.9210 - val_rmse: 14.8077 - learning_rate: 0.0010
# Epoch 5/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 930s 3s/step - loss: 27.7291 - mae: 7.6102 - rmse: 10.5710 - val_loss: 48.9562 - val_mae: 11.9671 - val_rmse: 16.9203 - learning_rate: 0.0010
# Epoch 6/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 931s 3s/step - loss: 26.2976 - mae: 7.2911 - rmse: 10.2013 - val_loss: 33.3631 - val_mae: 8.7531 - val_rmse: 12.2558 - learning_rate: 0.0010
# Epoch 7/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 929s 3s/step - loss: 25.7337 - mae: 7.1749 - rmse: 10.0399 - val_loss: 26.6069 - val_mae: 7.3092 - val_rmse: 10.2237 - learning_rate: 0.0010
# Epoch 8/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 930s 3s/step - loss: 24.4742 - mae: 6.9079 - rmse: 9.6840 - val_loss: 25.8765 - val_mae: 7.1791 - val_rmse: 10.1284 - learning_rate: 0.0010
# Epoch 9/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 917s 3s/step - loss: 23.7223 - mae: 6.7376 - rmse: 9.4517 - val_loss: 25.2858 - val_mae: 7.0863 - val_rmse: 10.0496 - learning_rate: 0.0010
# Epoch 10/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 926s 3s/step - loss: 22.9922 - mae: 6.5888 - rmse: 9.2431 - val_loss: 22.5029 - val_mae: 6.4531 - val_rmse: 9.2365 - learning_rate: 0.0010
# Epoch 11/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 931s 3s/step - loss: 22.2435 - mae: 6.4228 - rmse: 9.0640 - val_loss: 20.0650 - val_mae: 5.9125 - val_rmse: 8.4784 - learning_rate: 0.0010
# Epoch 12/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 941s 3s/step - loss: 22.1200 - mae: 6.3982 - rmse: 8.9901 - val_loss: 26.7999 - val_mae: 7.4789 - val_rmse: 9.8459 - learning_rate: 0.0010
# Epoch 13/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 922s 3s/step - loss: 21.2703 - mae: 6.2165 - rmse: 8.7183 - val_loss: 27.3753 - val_mae: 7.4569 - val_rmse: 10.8705 - learning_rate: 0.0010
# Epoch 14/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 922s 3s/step - loss: 20.6990 - mae: 6.0911 - rmse: 8.5756 - val_loss: 20.0316 - val_mae: 5.9496 - val_rmse: 8.4063 - learning_rate: 0.0010
# Epoch 15/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 927s 3s/step - loss: 20.6337 - mae: 6.0724 - rmse: 8.5524 - val_loss: 20.7621 - val_mae: 6.0498 - val_rmse: 8.7701 - learning_rate: 0.0010
# Epoch 16/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 20.2446 - mae: 5.9879 - rmse: 8.5081
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 926s 3s/step - loss: 19.9265 - mae: 5.9236 - rmse: 8.3852 - val_loss: 20.3174 - val_mae: 6.0099 - val_rmse: 8.5221 - learning_rate: 0.0010
# Epoch 17/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 948s 3s/step - loss: 18.7143 - mae: 5.6502 - rmse: 7.9939 - val_loss: 18.7668 - val_mae: 5.6623 - val_rmse: 7.9043 - learning_rate: 5.0000e-04
# Epoch 18/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 939s 3s/step - loss: 18.2674 - mae: 5.5681 - rmse: 7.8726 - val_loss: 17.9910 - val_mae: 5.4635 - val_rmse: 7.8232 - learning_rate: 5.0000e-04
# Epoch 19/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 924s 3s/step - loss: 18.1874 - mae: 5.5365 - rmse: 7.8591 - val_loss: 18.1995 - val_mae: 5.5773 - val_rmse: 7.7832 - learning_rate: 5.0000e-04
# Epoch 20/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 929s 3s/step - loss: 17.5648 - mae: 5.3997 - rmse: 7.6577 - val_loss: 20.1369 - val_mae: 5.9349 - val_rmse: 8.3385 - learning_rate: 5.0000e-04
# Epoch 21/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 949s 3s/step - loss: 17.1321 - mae: 5.3090 - rmse: 7.5249 - val_loss: 18.8676 - val_mae: 5.6717 - val_rmse: 8.1267 - learning_rate: 5.0000e-04
# Epoch 22/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 952s 3s/step - loss: 17.3842 - mae: 5.3615 - rmse: 7.5864 - val_loss: 19.4832 - val_mae: 5.8342 - val_rmse: 8.1398 - learning_rate: 5.0000e-04
# Epoch 23/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 17.0342 - mae: 5.2930 - rmse: 7.4259
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 970s 3s/step - loss: 16.9332 - mae: 5.2709 - rmse: 7.4082 - val_loss: 18.2668 - val_mae: 5.5513 - val_rmse: 7.9106 - learning_rate: 5.0000e-04
# Epoch 24/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 959s 3s/step - loss: 16.3170 - mae: 5.1329 - rmse: 7.2792 - val_loss: 16.6511 - val_mae: 5.2040 - val_rmse: 7.3296 - learning_rate: 2.5000e-04
# Epoch 25/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 947s 3s/step - loss: 15.6510 - mae: 4.9830 - rmse: 7.0863 - val_loss: 17.3632 - val_mae: 5.3535 - val_rmse: 7.6138 - learning_rate: 2.5000e-04
# Epoch 26/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1123s 4s/step - loss: 15.6646 - mae: 4.9914 - rmse: 7.0192 - val_loss: 17.2045 - val_mae: 5.3407 - val_rmse: 7.5157 - learning_rate: 2.5000e-04
# Epoch 27/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1148s 4s/step - loss: 15.4122 - mae: 4.9297 - rmse: 7.0031 - val_loss: 17.9238 - val_mae: 5.4882 - val_rmse: 7.6895 - learning_rate: 2.5000e-04
# Epoch 28/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 958s 3s/step - loss: 15.0572 - mae: 4.8549 - rmse: 6.8476 - val_loss: 17.0260 - val_mae: 5.2973 - val_rmse: 7.4371 - learning_rate: 2.5000e-04
# Epoch 29/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 15.3992 - mae: 4.9329 - rmse: 6.9193
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 951s 3s/step - loss: 15.2877 - mae: 4.9030 - rmse: 6.9214 - val_loss: 18.4825 - val_mae: 5.5990 - val_rmse: 7.8274 - learning_rate: 2.5000e-04
# Epoch 30/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 998s 3s/step - loss: 14.5820 - mae: 4.7420 - rmse: 6.7026 - val_loss: 16.6055 - val_mae: 5.1791 - val_rmse: 7.3574 - learning_rate: 1.2500e-04
# Epoch 31/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1034s 3s/step - loss: 14.2444 - mae: 4.6750 - rmse: 6.6005 - val_loss: 16.8604 - val_mae: 5.2492 - val_rmse: 7.3881 - learning_rate: 1.2500e-04
# Epoch 32/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 988s 3s/step - loss: 14.2626 - mae: 4.6743 - rmse: 6.5907 - val_loss: 16.7485 - val_mae: 5.1830 - val_rmse: 7.4700 - learning_rate: 1.2500e-04
# Epoch 33/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1008s 3s/step - loss: 14.0639 - mae: 4.6292 - rmse: 6.5673 - val_loss: 16.2194 - val_mae: 5.1045 - val_rmse: 7.2635 - learning_rate: 1.2500e-04
# Epoch 34/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 970s 3s/step - loss: 14.0219 - mae: 4.6256 - rmse: 6.5105 - val_loss: 17.0557 - val_mae: 5.2907 - val_rmse: 7.5552 - learning_rate: 1.2500e-04
# Epoch 35/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 971s 3s/step - loss: 13.9439 - mae: 4.6032 - rmse: 6.5248 - val_loss: 16.3336 - val_mae: 5.1149 - val_rmse: 7.3137 - learning_rate: 1.2500e-04
# Epoch 36/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 969s 3s/step - loss: 13.7702 - mae: 4.5742 - rmse: 6.4497 - val_loss: 17.2181 - val_mae: 5.3130 - val_rmse: 7.5137 - learning_rate: 1.2500e-04
# Epoch 37/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 976s 3s/step - loss: 13.7990 - mae: 4.5725 - rmse: 6.4767 - val_loss: 16.3675 - val_mae: 5.1431 - val_rmse: 7.3193 - learning_rate: 1.2500e-04
# Epoch 38/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1107s 4s/step - loss: 13.7765 - mae: 4.5650 - rmse: 6.4684 - val_loss: 16.2495 - val_mae: 5.1027 - val_rmse: 7.2875 - learning_rate: 1.2500e-04
# Epoch 39/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 933s 3s/step - loss: 13.6638 - mae: 4.5381 - rmse: 6.4173 - val_loss: 16.1266 - val_mae: 5.0911 - val_rmse: 7.2185 - learning_rate: 1.2500e-04
# Epoch 40/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 912s 3s/step - loss: 13.5931 - mae: 4.5269 - rmse: 6.3922 - val_loss: 16.0579 - val_mae: 5.0600 - val_rmse: 7.2345 - learning_rate: 1.2500e-04
# Epoch 41/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 930s 3s/step - loss: 13.4888 - mae: 4.5022 - rmse: 6.3795 - val_loss: 16.5589 - val_mae: 5.1789 - val_rmse: 7.3384 - learning_rate: 1.2500e-04
# Epoch 42/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 904s 3s/step - loss: 13.3900 - mae: 4.4743 - rmse: 6.3274 - val_loss: 16.2022 - val_mae: 5.0769 - val_rmse: 7.2450 - learning_rate: 1.2500e-04
# Epoch 43/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 908s 3s/step - loss: 13.2308 - mae: 4.4429 - rmse: 6.2759 - val_loss: 16.7894 - val_mae: 5.2156 - val_rmse: 7.4393 - learning_rate: 1.2500e-04
# Epoch 44/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 903s 3s/step - loss: 13.0965 - mae: 4.4103 - rmse: 6.2308 - val_loss: 16.2628 - val_mae: 5.0982 - val_rmse: 7.3116 - learning_rate: 1.2500e-04
# Epoch 45/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 13.1224 - mae: 4.4182 - rmse: 6.2220
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 929s 3s/step - loss: 13.0603 - mae: 4.4061 - rmse: 6.2331 - val_loss: 16.2731 - val_mae: 5.1165 - val_rmse: 7.2939 - learning_rate: 1.2500e-04
# Epoch 46/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 908s 3s/step - loss: 12.7326 - mae: 4.3213 - rmse: 6.1268 - val_loss: 17.3175 - val_mae: 5.3509 - val_rmse: 7.5507 - learning_rate: 6.2500e-05
# Epoch 47/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 903s 3s/step - loss: 12.7693 - mae: 4.3327 - rmse: 6.1501 - val_loss: 16.8503 - val_mae: 5.2382 - val_rmse: 7.4362 - learning_rate: 6.2500e-05
# Epoch 48/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 16484s 56s/step - loss: 12.6935 - mae: 4.3185 - rmse: 6.1094 - val_loss: 15.8864 - val_mae: 4.9965 - val_rmse: 7.2008 - learning_rate: 6.2500e-05
# Epoch 49/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1024s 3s/step - loss: 12.7127 - mae: 4.3207 - rmse: 6.1205 - val_loss: 16.4198 - val_mae: 5.1405 - val_rmse: 7.3075 - learning_rate: 6.2500e-05
# Epoch 50/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 980s 3s/step - loss: 12.5626 - mae: 4.2985 - rmse: 6.0609 - val_loss: 16.0165 - val_mae: 5.0606 - val_rmse: 7.1873 - learning_rate: 6.2500e-05
# Epoch 51/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 977s 3s/step - loss: 12.4754 - mae: 4.2695 - rmse: 6.0398 - val_loss: 16.9531 - val_mae: 5.2476 - val_rmse: 7.5060 - learning_rate: 6.2500e-05
# Epoch 52/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 992s 3s/step - loss: 12.5104 - mae: 4.2735 - rmse: 6.0647 - val_loss: 16.5681 - val_mae: 5.1679 - val_rmse: 7.3872 - learning_rate: 6.2500e-05
# Epoch 53/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 12.3845 - mae: 4.2523 - rmse: 5.9716
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 995s 3s/step - loss: 12.3980 - mae: 4.2572 - rmse: 6.0133 - val_loss: 16.6839 - val_mae: 5.1982 - val_rmse: 7.4282 - learning_rate: 6.2500e-05
# Epoch 54/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1004s 3s/step - loss: 12.2311 - mae: 4.2155 - rmse: 5.9488 - val_loss: 16.1734 - val_mae: 5.0941 - val_rmse: 7.2563 - learning_rate: 3.1250e-05
# Epoch 55/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1005s 3s/step - loss: 12.3248 - mae: 4.2362 - rmse: 5.9906 - val_loss: 16.5902 - val_mae: 5.1892 - val_rmse: 7.3851 - learning_rate: 3.1250e-05
# Epoch 56/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 987s 3s/step - loss: 12.3191 - mae: 4.2450 - rmse: 5.9941 - val_loss: 16.4447 - val_mae: 5.1544 - val_rmse: 7.3191 - learning_rate: 3.1250e-05
# Epoch 57/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1054s 3s/step - loss: 12.2308 - mae: 4.2203 - rmse: 5.9786 - val_loss: 16.2784 - val_mae: 5.1230 - val_rmse: 7.2850 - learning_rate: 3.1250e-05
# Epoch 58/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 12.3197 - mae: 4.2420 - rmse: 5.9634
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 998s 3s/step - loss: 12.2394 - mae: 4.2251 - rmse: 5.9517 - val_loss: 16.3495 - val_mae: 5.1328 - val_rmse: 7.2843 - learning_rate: 3.1250e-05
# Epoch 59/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 981s 3s/step - loss: 12.0089 - mae: 4.1709 - rmse: 5.8785 - val_loss: 16.3182 - val_mae: 5.1321 - val_rmse: 7.2776 - learning_rate: 1.5625e-05
# Epoch 60/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 955s 3s/step - loss: 12.0551 - mae: 4.1754 - rmse: 5.8820 - val_loss: 16.3118 - val_mae: 5.1277 - val_rmse: 7.2913 - learning_rate: 1.5625e-05
# Epoch 61/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 990s 3s/step - loss: 12.0368 - mae: 4.1733 - rmse: 5.8819 - val_loss: 16.3921 - val_mae: 5.1455 - val_rmse: 7.3008 - learning_rate: 1.5625e-05
# Epoch 62/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 991s 3s/step - loss: 11.9275 - mae: 4.1509 - rmse: 5.8653 - val_loss: 16.1827 - val_mae: 5.0974 - val_rmse: 7.2458 - learning_rate: 1.5625e-05
# Epoch 63/200
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 12.0782 - mae: 4.1803 - rmse: 5.9021
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1035s 3s/step - loss: 12.0947 - mae: 4.1837 - rmse: 5.9146 - val_loss: 16.3761 - val_mae: 5.1364 - val_rmse: 7.3172 - learning_rate: 1.5625e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.

# %% [markdown]
# # 7) Evaluación y guardado

# %%
print("Evaluando en test...")
test_metrics = model.evaluate(test_ds, verbose=0)
print(dict(zip(model.metrics_names, test_metrics)))
# Out:
# Evaluando en test...
# {'loss': 15.678214073181152, 'compile_metrics': 4.9071946144104}

# %%
# plot results for age
import matplotlib.pyplot as plt
loss = history.history['mae']
val_loss = history.history['val_mae']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training MAE')
plt.plot(epochs, val_loss, 'r', label='Validation MAE')
plt.title('MAE Graph')
plt.legend()
plt.show()

# %%
def predict_age(image_path):
    img_bytes = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img_bytes, channels=3)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.image.convert_image_dtype(img, tf.float32)
    pred = model.predict(tf.expand_dims(img, 0), verbose=0)[0,0]
    return float(pred)

# %%
def true_age_from_path(p):
    # Para UTKFace: "23_0_0_....jpg"
    return float(os.path.basename(p).split("_")[0])

# %%
p = test_files[0]                     # o random.choice(test_files)
pred = predict_age(p)
print(os.path.basename(p), "→ pred =", pred, " | true =", true_age_from_path(p))
# Out:
# 30_0_2_20170116170814123.jpg.chip.jpg → pred = 27.091142654418945  | true = 30.0

# %%
for p in random.sample(test_files, k=11):
    y_true = true_age_from_path(p)
    y_pred = predict_age(p)
    print(f"{os.path.basename(p):32s} true={y_true:5.1f}  pred={y_pred:5.1f}  err={abs(y_pred-y_true):5.1f}")
# Out:
# 65_0_2_20170112222023530.jpg.chip.jpg true= 65.0  pred= 78.2  err= 13.2
# 68_0_0_20170104213635701.jpg.chip.jpg true= 68.0  pred= 66.7  err=  1.3
# 28_1_2_20170116162739672.jpg.chip.jpg true= 28.0  pred= 35.0  err=  7.0
# 5_0_0_20170110213615044.jpg.chip.jpg true=  5.0  pred=  3.4  err=  1.6
# 61_0_3_20170104210003146.jpg.chip.jpg true= 61.0  pred= 42.0  err= 19.0
# 40_0_2_20170116192534886.jpg.chip.jpg true= 40.0  pred= 33.3  err=  6.7
# 5_1_0_20170109194058911.jpg.chip.jpg true=  5.0  pred=  2.7  err=  2.3
# 1_1_2_20161219204636789.jpg.chip.jpg true=  1.0  pred=  1.0  err=  0.0
# 29_1_1_20170116021333343.jpg.chip.jpg true= 29.0  pred= 32.2  err=  3.2
# 58_0_0_20170117191924885.jpg.chip.jpg true= 58.0  pred= 53.8  err=  4.2
# 31_0_3_20170104232355440.jpg.chip.jpg true= 31.0  pred= 27.9  err=  3.1

# %%
print(predict_age(r'C:/Users/sebas/OneDrive/Desktop/Cosas mias/Fotos de perfil/cropped-EDUAR  MACIAS  SANCHEZ  DIGITAL.jpg'))
# Out:
# 18.9373722076416
